# %% [markdown]
# **Руслан, привет!** 👋
#
# Меня зовут Артем Пиляй. Я буду проверять твой проект. В рамках корпоративной этики мы общаемся на «ты». Но если лучше на «Вы», то нужно обозначить это сразу.
#
# В тетрадке есть комментарии к проекту, они будут в отдельных ячейках Markdown.
#
# <div class="alert alert-danger">
#
# **Артём:** ✋ Такой комментарий **нужно исправить** обязательно, он критически влияет на удачное выполнение проекта.
#
# </div>
#
# <div class="alert alert-warning">
#
# **Артём:** 👉 Если таких комментариев в проекте **не больше трех**, то проект будет принят. Но есть два исключения, при которых я приму проект с любым количеством таких комментариев:
#
# * если у тебя дедлайн, тогда оставь в начале 👆 проекта комментарий «Дедлайн, специальность (DA/DS/DA+/DS+), и номер когорты»;
# * если ты считаешь, что для успешного трудоустройства и для успешной работы в команде тебе это не нужно, тогда оставь в начале проекта комментарий «Не нужно».
# </div>
#
# <div class="alert alert-success">
#
# **Артём:** 👍 А это **самый главный комментарий**, значит все сделано хорошо. 😉
#
# </div>
#
# <div class="alert alert-info">
#
# **Артём:** ✍️ В таких комментариях я оставляю подсказки как сделать **твой проект ещё лучше**.
#
# </div>
#
# ---
#
# **Распространенные ошибки**
#
# <div class="alert alert-danger">
#
# **Артём:** ✋ Не перемещай и не удаляй мои комментарии. Лучше, чтобы твои ответы на мои комментарии шли по очереди, как сообщения в мессенджере. Это ускорит проверку.
#
# </div>
#
# <div class="alert alert-danger">
#
# **Артём:** ✋ Проверь проект на работоспособность перед отправкой на проверку. Это важный навык, который тебе пригодится как на собеседовании, при выполнении тестового задания, так и перед совещанием у руководства компании. Помни, ревьеры не вносят изменения в код, даже если это путь к датасету или ячейка в неверном формате (code/mardown).
#
# </div>
#
# <div class="alert alert-info">
#
# **Артём:** ✍️ Кстати, смотри как можно сделать, чтобы датасет грузился и локально, и в JupyterHub:
#
# ```py
# try:
#     df = pd.read_csv('C:/Users/Student/Desktop/dataset.csv')
# except:
#     df = pd.read_csv('/datasets/dataset.csv')
# ```
#
# Используя эту конструкцию в будущих проектах, ты будешь спокойно отправлять проект на проверку зная, что он будет работать.
#
# </div>
#
# <div class="alert alert-danger">
#
# **Артём:** ✋ Проект должен быть структурирован. Где названия разделов и подразделов будут записаны в ячейках Markdown.
#
# </div>
#
# <div class="alert alert-danger">
#
# **Артём:** ✋ Если с твоим проектом будет знакомиться другой человек, например рекрутер или старший дата специалист, в нем должны быть описаны поставленные задачи, содержание датасета, промежуточные и финальные выводы. Как правило, заказчик читает только финальный вывод, поэтому важно добавить информацию о проведенном исследовании, применить форматирование текста, в общем, сделать красиво, чтобы было понятно, что проведено настоящее исследование и выводу можно верить.
#
# </div>
#
# <div class="alert alert-warning">
#
# **Артём:** 👉 Длинный код и комментарии нужно переносить на новую строку. Согласись, коллеги не оценят, если им придется тратить время на пролистывание ячеек. Согласно международному стандарту [PEP8](https://www.python.org/dev/peps/pep-0008/) длина строки не должна превышать 79 символов.
# Вот как можно перенести код на новую строку:
#
# ```py
# # Переносить можно код внутри скобки
# example = (2 *
#            2)
# ```
# Конечно, я не считаю сколько символов в строке, главное, чтобы код или комментарий не ушел за пределы ячейки (зависит от разрешения экрана). Если ушел, то это желтый комментарий для каждой нечитаемой ячейки.
#
# </div>
#
# <div class="alert alert-warning">
#
# **Артём:** 👉 Тимлид, старший дата специалист или ревьюер ценят твое и своё время, подсвечивай свои комментарии в ячейках Markdown. Шаблон я тебе оставил ниже. Подробнее про синтаксис Markdown, с примерами, можно почитать [здесь](https://paulradzkov.com/2014/markdown_cheatsheet/?).
#
# </div>
#
# <div class="alert alert-success">
#
# **Артём:** 👍 Буду рад, если воспользуешься моими советами. Они тебе помогут при трудоустройстве и при работе в команде. Если в ходе проведения исследования возникнут вопросы, не стесняйся задавай. 🙂
# </div>
#
# **Поехали!** 🚀 👨‍🚀

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# **Имя:** Это шаблон для тебя. Такой комментарий можно быстро найти.

# %% [markdown]
# ---

# %% [markdown]
# <div class="alert alert-danger">
#
# **Артём:** ✋ Руслан, проект не написан до конца, закончи исследование и присылай на проверку.
#
# Жду новую версию проекта. 🙂
#
# </div>

# %% [markdown]
# <a id="cell_80"></a>
# <div class="alert alert-danger">
#
# **Артём:** ✋✋ Руслан, ты переаутал логику. Если бы только 10% клиентов возвращали кредиты, то банки бы обанкротились. Это 10% тех кто не возвращает. Измени промежуточные выводы и допиши финальный и можно идти к заказчику.
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
#
# **Артём:** ✋✋✋ Ты делаешь некорректные выводы. Посмотри [подсказку](#cell_3_1)
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
#
# **Артём:** ✋✋✋✋ Ты не исправил вывод в промежуточных выводах в последнем шаге. и не дал ответ заказчику на поставленные вопросы. Я не могу принять проект пока ты не ответишь корректно на вопросы.
#
# В брифе:
#
# Ответьте на вопросы
#
# * Есть ли зависимость между количеством детей и возвратом кредита в срок?
# * Есть ли зависимость между семейным положением и возвратом кредита в срок?
# * Есть ли зависимость между уровнем дохода и возвратом кредита в срок?
# * Как разные цели кредита влияют на его возврат в срок?
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** ✌️ Руслан, спасибо за хорошую работу и внесенные корректировки! Критических замечаний нет.
#
# Поздравляю, **проект принят!** 🥳 🎉 Ты молодец!
#
# Желаю тебе успехов в дальнейшем обучении. 😉
#
# </div>

# %% [markdown]
# ---

# %% [markdown]
# # Исследование надежности заемщиков.

# %% [markdown]
# <a id="cell_0"></a>
# <div class="alert alert-danger">
#
# **Артём:** ✋ Добавь описание проекта и отформатированное описание столбцов датасета, чтобы человек, который будет знакомится с твоим портфолио понимал, что ты исследуешь.
#
# Пример форматирования:
#
# - `first_column` — содержание столбца 1;
# - `second_column` — содержание столбца 2;
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍👍 Хорошо.
#
# </div>

# %% [markdown]
# Заказчик — кредитный отдел банка. Нужно разобраться, влияет ли семейное положение и количество детей клиента на факт погашения кредита в срок. Входные данные от банка — статистика о платёжеспособности клиентов.
# Результаты исследования будут учтены при построении модели кредитного скоринга — специальной системы, которая оценивает способность потенциального заёмщика вернуть кредит банку. Ниже представлены описания столбцов датасета.

# %% [markdown]
# children — количество детей в семье

# %% [markdown]
# days_employed — общий трудовой стаж в днях

# %% [markdown]
# dob_years — возраст клиента в годах

# %% [markdown]
# education — уровень образования клиента

# %% [markdown]
# education_id — идентификатор уровня образования

# %% [markdown]
# family_status — семейное положение

# %% [markdown]
# family_status_id — идентификатор семейного положения

# %% [markdown]
# gender — пол клиента

# %% [markdown]
# income_type — тип занятости

# %% [markdown]
# debt — имел ли задолженность по возврату кредитов

# %% [markdown]
# total_income — ежемесячный доход

# %% [markdown]
# purpose — цель получения кредита

# %% [markdown]
# ### Шаг 1. Обзор данных

# %%
import pandas as pd

# %% [markdown]
# Изучим датасет, просмотрим начало, конец и описательную статистику.

# %%
df = pd.read_csv('/datasets/data.csv')
df.head(10)
# Out:
#    children  days_employed  dob_years education  education_id  \
# 0         1   -8437.673028         42    высшее             0
# 1         1   -4024.803754         36   среднее             1
# 2         0   -5623.422610         33   Среднее             1
# 3         3   -4124.747207         32   среднее             1
# 4         0  340266.072047         53   среднее             1
# 5         0    -926.185831         27    высшее             0
# 6         0   -2879.202052         43    высшее             0
# 7         0    -152.779569         50   СРЕДНЕЕ             1
# 8         2   -6929.865299         35    ВЫСШЕЕ             0
# 9         0   -2188.756445         41   среднее             1
#
#       family_status  family_status_id gender income_type  debt   total_income  \
# 0   женат / замужем                 0      F   сотрудник     0  253875.639453
# 1   женат / замужем                 0      F   сотрудник     0  112080.014102
# ...

# %%
df.tail(10)
# Out:
#        children  days_employed  dob_years       education  education_id  \
# 21515         1    -467.685130         28         среднее             1
# 21516         0    -914.391429         42          высшее             0
# 21517         0    -404.679034         42          высшее             0
# 21518         0  373995.710838         59         СРЕДНЕЕ             1
# 21519         1   -2351.431934         37  ученая степень             4
# 21520         1   -4529.316663         43         среднее             1
# 21521         0  343937.404131         67         среднее             1
# 21522         1   -2113.346888         38         среднее             1
# 21523         3   -3112.481705         38         среднее             1
# 21524         2   -1984.507589         40         среднее             1
#
#           family_status  family_status_id gender income_type  debt  \
# 21515   женат / замужем                 0      F   сотрудник     1
# ...

# %%
df.describe()
# Out:
#            children  days_employed     dob_years  education_id  \
# count  21525.000000   19351.000000  21525.000000  21525.000000
# mean       0.538908   63046.497661     43.293380      0.817236
# std        1.381587  140827.311974     12.574584      0.548138
# min       -1.000000  -18388.949901      0.000000      0.000000
# 25%        0.000000   -2747.423625     33.000000      1.000000
# 50%        0.000000   -1203.369529     42.000000      1.000000
# 75%        1.000000    -291.095954     53.000000      1.000000
# max       20.000000  401755.400475     75.000000      4.000000
#
#        family_status_id          debt  total_income
# count      21525.000000  21525.000000  1.935100e+04
# mean           0.972544      0.080883  1.674223e+05
# std            1.420324      0.272661  1.029716e+05
# min            0.000000      0.000000  2.066726e+04
# 25%            0.000000      0.000000  1.030532e+05
# 50%            0.000000      0.000000  1.450179e+05
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   children          21525 non-null  int64
#  1   days_employed     19351 non-null  float64
#  2   dob_years         21525 non-null  int64
#  3   education         21525 non-null  object
#  4   education_id      21525 non-null  int64
#  5   family_status     21525 non-null  object
#  6   family_status_id  21525 non-null  int64
#  7   gender            21525 non-null  object
#  8   income_type       21525 non-null  object
#  9   debt              21525 non-null  int64
#  10  total_income      19351 non-null  float64
#  11  purpose           21525 non-null  object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 2.0+ MB

# %% [markdown]
# Выявленные проблемы:
# 1) Присутствуют отрицательные значения
# 2) Отсутствуют строки
# 3) Разный регистр букв в названии
# 4) Минимальное значение в возрасте - 0
# 5) Присутсвуют дубликаты
# 6) Неудобные данные, дни стажа перевести в года

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Хорошо.
#
# </div>

# %% [markdown]
# ### Шаг 2.1 Заполнение пропусков

# %%
# Подсчитаем суммарное количество пропусков
df.isnull().sum()
# Out:
# children               0
# days_employed       2174
# dob_years              0
# education              0
# education_id           0
# family_status          0
# family_status_id       0
# gender                 0
# income_type            0
# debt                   0
# total_income        2174
# purpose                0
# dtype: int64

# %% [markdown]
# Одинаковое количество пропусков в днях работы и в доходе в месяц. Веротно, эти люди никогда не работали, так как молоды или работали не официально. Либо данные просто некорректно выгружены. Заполнить пропуски медианным значением будет неккоректно. Такое действие повысит шанс получени кредита, а так как заказчик - кредитный отдел банка им будет важен достоверный результат о кредитоспособности клиентов. В иных случах заполнение пропущенных значений медианным является оптимальным решением, ведь медианные значения в отличае от среднего арифметического предоставляют более реалистичную картину.

# %% [markdown]
# <div class="alert alert-warning">
#
# **Артём:** 👉 Заполнить медианой будет корректно, поскольку заполнять можно в связке с другими столбцами.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
#
# **Артём:** ✍️ Например так:
#
# ```py
# # Заполнил пустое поле дохода медианным значением дохода для соответствующего типа занятости
# df["total_income"] = df.groupby("income_type")["total_income"].transform(lambda x: x.fillna(x.median()))
# # или
# df['median'] = df.groupby('income_type')['total_income'].transform('median')
# df['total_income'] = df['total_income'].fillna(df['median'])
# ```
#
# </div>

# %%
# Заменим пропуски на нули.
df['days_employed'] = df['days_employed'].fillna(0)

# %%
df['total_income'] = df['total_income'].fillna(0)

# %%
# Проверим
df.isnull().sum()
# Out:
# children            0
# days_employed       0
# dob_years           0
# education           0
# education_id        0
# family_status       0
# family_status_id    0
# gender              0
# income_type         0
# debt                0
# total_income        0
# purpose             0
# dtype: int64

# %% [markdown]
# ### Шаг 2.2 Проверка данных на аномалии и исправления.

# %% [markdown]
# Исследуем все столбцы в отдельности

# %%
# количество детей в семье
df['children'].unique()
# Out:
# array([ 1,  0,  3,  2, -1,  4, 20,  5])

# %%
# Значения -1 и 20 подозрительны, проверим количество таких строк
df[df['children'] == -1]['children'].count()
# Out:
# 47

# %%
# Подсчитаем количество строк с 20 детьми
df[df['children'] == 20]['children'].count()
# Out:
# 76

# %%
# Много людей с 20 детьми, сгруппируем по возрасту, чтобы убедиться в корректности данных
df[df['children'] == 20].groupby('dob_years')['dob_years'].count()
# Out:
# dob_years
# 0     1
# 21    1
# 23    1
# 24    1
# 25    1
# 26    1
# 27    2
# 29    2
# 30    3
# 31    2
# 32    2
# 33    2
# 34    3
# 35    2
# 36    2
# 37    4
# 38    1
# 39    1
# 40    4
# 41    2
# 42    3
# 43    2
# 44    2
# 45    3
# 46    3
# 48    1
# 49    3
# 50    3
# 51    1
# 52    1
# 53    1
# 54    1
# 55    1
# 56    5
# 57    1
# 59    2
# 60    1
# 61    1
# 62    1
# 64    1
# 69    1
# Name: dob_years, dtype: int64

# %% [markdown]
# Если бы данные предоставлялись за несколько десятилетий, можно было бы предположить, что имеет место быть некая программа кредитования для людей с 20 детьми. Однако в нашем случае это не так, так что считаем это ошибкой, что 20 это на самом деле 2.

# %%
# Общий трудовой стаж в днях
df['days_employed'].describe()
# Out:
# count     21525.000000
# mean      56678.874622
# std      134870.763085
# min      -18388.949901
# 25%       -2518.168900
# 50%        -982.531720
# 75%           0.000000
# max      401755.400475
# Name: days_employed, dtype: float64

# %%
# Есть отрицательные значения, значения не в целых числах.

# %%
# Разберемся с возрастом
df['dob_years'].unique()
# Out:
# array([42, 36, 33, 32, 53, 27, 43, 50, 35, 41, 40, 65, 54, 56, 26, 48, 24,
#        21, 57, 67, 28, 63, 62, 47, 34, 68, 25, 31, 30, 20, 49, 37, 45, 61,
#        64, 44, 52, 46, 23, 38, 39, 51,  0, 59, 29, 60, 55, 58, 71, 22, 73,
#        66, 69, 19, 72, 70, 74, 75])

# %%
# Подсчитаем людей с возрастом 0
df[df['dob_years'] == 0]['dob_years'].count()
# Out:
# 101

# %%
# Образование
len(df['education'].unique())
# Out:
# 15

# %%
# Университетов 15, а в ID только 5
df['education_id'].unique()
# Out:
# array([0, 1, 2, 3, 4])

# %%
# Семейный статус дл удобства сразу приведем к нижнему регистру
df['family_status'] = df['family_status'].str.lower()

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Молодец, оптимальный метод.
#
# </div>

# %%
df['family_status'].unique()
# Out:
# array(['женат / замужем', 'гражданский брак', 'вдовец / вдова',
#        'в разводе', 'не женат / не замужем'], dtype=object)

# %%
# Тут все в порядке
df['family_status_id'].unique()
# Out:
# array([0, 1, 2, 3, 4])

# %%
# Посмотрим что с полом
df['gender'].unique()
# Out:
# array(['F', 'M', 'XNA'], dtype=object)

# %%
# Есть одна ошибка
df[df['gender'] == 'XNA'].count()
# Out:
# children            1
# days_employed       1
# dob_years           1
# education           1
# education_id        1
# family_status       1
# family_status_id    1
# gender              1
# income_type         1
# debt                1
# total_income        1
# purpose             1
# dtype: int64

# %%
# Статус в порядке
df['income_type'].unique()
# Out:
# array(['сотрудник', 'пенсионер', 'компаньон', 'госслужащий',
#        'безработный', 'предприниматель', 'студент', 'в декрете'],
#       dtype=object)

# %%
# Доход неудобен для анализа, можно привести значения к целым числам,вне зависимости от валюты
# На кредитноспособность это не повлияет
df['total_income'].unique()
# Out:
# array([253875.6394526 , 112080.01410244, 145885.95229686, ...,
#         89672.56115303, 244093.05050043,  82047.41889948])

# %% [markdown]
# <div class="alert alert-warning">
#
# **Артём:** 👉 Смотри – этот комментарий невозможно прочитать, не пролистав ячейку. Как ты думаешь, коллеги оценят, что им придется тратить время на пролистывание ячеек? 😉
# Согласно международному стандарту [PEP8](https://www.python.org/dev/peps/pep-0008/) в строке должно быть не больше 79 символов.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍👍 Спасибо.
#
# </div>

# %%
# Теперь проверим цели, тут хорошо было бы выделить из массы значений ключевые слова
df['purpose'].unique()
# Out:
# array(['покупка жилья', 'приобретение автомобиля',
#        'дополнительное образование', 'сыграть свадьбу',
#        'операции с жильем', 'образование', 'на проведение свадьбы',
#        'покупка жилья для семьи', 'покупка недвижимости',
#        'покупка коммерческой недвижимости', 'покупка жилой недвижимости',
#        'строительство собственной недвижимости', 'недвижимость',
#        'строительство недвижимости', 'на покупку подержанного автомобиля',
#        'на покупку своего автомобиля',
#        'операции с коммерческой недвижимостью',
#        'строительство жилой недвижимости', 'жилье',
#        'операции со своей недвижимостью', 'автомобили',
#        'заняться образованием', 'сделка с подержанным автомобилем',
#        'получение образования', 'автомобиль', 'свадьба',
#        'получение дополнительного образования', 'покупка своего жилья',
#        'операции с недвижимостью', 'получение высшего образования',
#        'свой автомобиль', 'сделка с автомобилем',
# ...

# %%
# Узнаем количество уникальных значений в целях кредита — 38
unique_purposes = df['purpose'].unique().tolist()
unique_purposes
# Out:
# ['покупка жилья',
#  'приобретение автомобиля',
#  'дополнительное образование',
#  'сыграть свадьбу',
#  'операции с жильем',
#  'образование',
#  'на проведение свадьбы',
#  'покупка жилья для семьи',
#  'покупка недвижимости',
#  'покупка коммерческой недвижимости',
#  'покупка жилой недвижимости',
#  'строительство собственной недвижимости',
#  'недвижимость',
#  'строительство недвижимости',
#  'на покупку подержанного автомобиля',
#  'на покупку своего автомобиля',
#  'операции с коммерческой недвижимостью',
#  'строительство жилой недвижимости',
#  'жилье',
#  'операции со своей недвижимостью',
#  'автомобили',
#  'заняться образованием',
#  'сделка с подержанным автомобилем',
#  'получение образования',
#  'автомобиль',
#  'свадьба',
#  'получение дополнительного образования',
#  'покупка своего жилья',
#  'операции с недвижимостью',
#  'получение высшего образования',
#  'свой автомобиль',
#  'сделка с автомобилем',
#  'профильное образование',
#  'высшее образование',
# ...

# %% [markdown]
# Присутсвуют аномалии. Необходимо исправить количество детей с 20 на 2, и с -1 на 1. Изменить значения с возрастом людей равных 0. Убрать отрицательные значения в трудовом стаже и заменить дни стажа на года для удобства. В образовании приведём строки к нижнему регистру, дабы уровень образования совпадал с идентификатором уровня образования.

# %% [markdown]
# <a id="cell_28"></a>
# <div class="alert alert-danger">
#
# **Артём:** ✋ Ты изучил данные, но не написал какие аномалии нашел, и что с ними будешь делать. Напиши промежуточный вывод.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍👍 Верно.
#
# </div>

# %% [markdown]
# ### Шаг 2.3. Изменение типов данных.

# %% [markdown]
# Изменим данные в столбцах и приведем к нормальному виду

# %%
# Дети
# Заменим -1 на 1
df['children'] = df['children'].replace(-1, 1)

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Такой подход возможен.
#
# </div>

# %%
# Проверим замену
df[df['children'] == -1]['children'].count()
# Out:
# 0

# %%
# Заменим 20 на 2
df['children'] = df['children'].replace(20, 2)

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Согласен.
#
# </div>

# %%
# И проверим
df[df['children'] == 20]['children'].count()
# Out:
# 0

# %%
df['children'].unique()
# Out:
# array([1, 0, 3, 2, 4, 5])

# %%
# Трудовой стаж; в днях, избавимся от отрицательных значений
df['days_employed'] = df['days_employed'].abs()

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Верно.
#
# </div>

# %%
df['days_employed'].describe()
# Out:
# count     21525.000000
# mean      60156.419005
# std      133355.929525
# min           0.000000
# 25%         610.652074
# 50%        1808.053434
# 75%        4779.587738
# max      401755.400475
# Name: days_employed, dtype: float64

# %%
# Стало лучше, но максимальные значения выглядят как "столько не работают"
# Найдем самого великовозрастного человека в наборе
# Если предположить, что он работал с 16 лет, то:
max_days_of_employment = (df['dob_years'].max() - 16) * 365
max_days_of_employment 
# Получим количество дней, по которым можно сделать отсев
# Out:
# 21535

# %%
df[df['days_employed'] > max_days_of_employment]['days_employed'].count() / 21525 * 100
# Многовато, почти 16% от всего набора, но перевести в года и добавить новый столбец не помешает
# Out:
# 16.004645760743323

# %%
# Можно перевести в года, создав новый столбец и убрав старый
df['years_employed'] = df['days_employed'] / 365

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Можно.
#
# </div>

# %%
df['years_employed'] = df['years_employed'].astype(int)

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Хорошо.
#
# </div>

# %%
# Удалим столбец с днями, оставим только года
# Вопрос вызывает только те, кто работает почти тысячу лет, не ясно откуда взялась аномалия
del df['days_employed']

# %% [markdown]
# <div class="alert alert-warning">
#
# **Артём:** 👉 И к какому выводу ты пришел? Как появились данные с аномальным стажем?
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍👍 Это похоже на часы.
#
# </div>

# %%
df.head()
# Out:
#    children  dob_years education  education_id     family_status  \
# 0         1         42    высшее             0   женат / замужем
# 1         1         36   среднее             1   женат / замужем
# 2         0         33   Среднее             1   женат / замужем
# 3         3         32   среднее             1   женат / замужем
# 4         0         53   среднее             1  гражданский брак
#
#    family_status_id gender income_type  debt   total_income  \
# 0                 0      F   сотрудник     0  253875.639453
# 1                 0      F   сотрудник     0  112080.014102
# 2                 0      M   сотрудник     0  145885.952297
# 3                 0      M   сотрудник     0  267628.550329
# 4                 1      F   пенсионер     0  158616.077870
#
#                       purpose  years_employed
# 0               покупка жилья              23
# 1     приобретение автомобиля              11
# 2               покупка жилья              15
# ...

# %%
# В образовании приведем строки к нижнему регистру
df['education'] = df['education'].str.lower()

# %%
# Теперь уровень образования равен идентификатору уровня образования
df['education'].unique()
# Out:
# array(['высшее', 'среднее', 'неоконченное высшее', 'начальное',
#        'ученая степень'], dtype=object)

# %%
# Приведем доход к целому состоянию
df['total_income'] = df['total_income'].astype(int)

# %%
df.head()
# Out:
#    children  dob_years education  education_id     family_status  \
# 0         1         42    высшее             0   женат / замужем
# 1         1         36   среднее             1   женат / замужем
# 2         0         33   среднее             1   женат / замужем
# 3         3         32   среднее             1   женат / замужем
# 4         0         53   среднее             1  гражданский брак
#
#    family_status_id gender income_type  debt  total_income  \
# 0                 0      F   сотрудник     0        253875
# 1                 0      F   сотрудник     0        112080
# 2                 0      M   сотрудник     0        145885
# 3                 0      M   сотрудник     0        267628
# 4                 1      F   пенсионер     0        158616
#
#                       purpose  years_employed
# 0               покупка жилья              23
# 1     приобретение автомобиля              11
# 2               покупка жилья              15
# ...

# %%
# Узнаем количество уникальных значений в целях кредита — 38
unique_purposes = df['purpose'].unique().tolist()
unique_purposes
# Out:
# ['покупка жилья',
#  'приобретение автомобиля',
#  'дополнительное образование',
#  'сыграть свадьбу',
#  'операции с жильем',
#  'образование',
#  'на проведение свадьбы',
#  'покупка жилья для семьи',
#  'покупка недвижимости',
#  'покупка коммерческой недвижимости',
#  'покупка жилой недвижимости',
#  'строительство собственной недвижимости',
#  'недвижимость',
#  'строительство недвижимости',
#  'на покупку подержанного автомобиля',
#  'на покупку своего автомобиля',
#  'операции с коммерческой недвижимостью',
#  'строительство жилой недвижимости',
#  'жилье',
#  'операции со своей недвижимостью',
#  'автомобили',
#  'заняться образованием',
#  'сделка с подержанным автомобилем',
#  'получение образования',
#  'автомобиль',
#  'свадьба',
#  'получение дополнительного образования',
#  'покупка своего жилья',
#  'операции с недвижимостью',
#  'получение высшего образования',
#  'свой автомобиль',
#  'сделка с автомобилем',
#  'профильное образование',
#  'высшее образование',
# ...

# %% [markdown]
# Выделим цели кредитов руками:
#
# 1) автомобиль
# 2) недвижимость
# 3) образование
# 4) свадьба

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Правильно.
#
# </div>

# %% [markdown]
# Привели значения в порядок, избавились от аномалий и непонятных значений. Остались вопросы, но на работу с данными они не повлияют.

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Хорошо, что смотришь на данные в контексте поставленной задачи.
#
# </div>

# %% [markdown]
# Шаг 2.4. Удаление дубликатов.

# %% [markdown]
# Поищем дубликаты, приведем названия столбцов в порядок, поработаем с признаками.

# %%
df.columns.tolist()
# Out:
# ['children',
#  'dob_years',
#  'education',
#  'education_id',
#  'family_status',
#  'family_status_id',
#  'gender',
#  'income_type',
#  'debt',
#  'total_income',
#  'purpose',
#  'years_employed']

# %%
# Посмотрим есть ли дубли
df.duplicated().sum()
# Out:
# 71

# %%
# Удалим дубли и сбросим индекс
df = df.drop_duplicates().reset_index(drop=True)

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Нет дубликатов – нет проблем. 😀
#
# </div>

# %%
# Проверим удалились ли дубли
df.duplicated().sum()
# Out:
# 0

# %%
df.head(15)
# Out:
#     children  dob_years            education  education_id     family_status  \
# 0          1         42               высшее             0   женат / замужем
# 1          1         36              среднее             1   женат / замужем
# 2          0         33              среднее             1   женат / замужем
# 3          3         32              среднее             1   женат / замужем
# 4          0         53              среднее             1  гражданский брак
# 5          0         27               высшее             0  гражданский брак
# 6          0         43               высшее             0   женат / замужем
# 7          0         50              среднее             1   женат / замужем
# 8          2         35               высшее             0  гражданский брак
# 9          0         41              среднее             1   женат / замужем
# 10         2         36               высшее             0   женат / замужем
# ...

# %%
# Был 71 дубль, они появились из-за ошибки правил валидации на сервере
# ВПР не сумел разглядеть схожестей и продублировал

# %% [markdown]
# <div class="alert alert-warning">
#
# **Артём:** 👉 Перенеси комментарий.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍👍 Спасибо.
#
# </div>

# %% [markdown]
# ### Шаг 2.5. Формирование дополнительных датафреймов словарей, декомпозиция исходного датафрейма.

# %%
# Создаем новый датафрейм, где каждому значению education будет присвоен его номер в education_id
education_df = df[['education','education_id']]

# %%
education_df.head(10)
# Out:
#   education  education_id
# 0    высшее             0
# 1   среднее             1
# 2   среднее             1
# 3   среднее             1
# 4   среднее             1
# 5    высшее             0
# 6    высшее             0
# 7   среднее             1
# 8    высшее             0
# 9   среднее             1

# %%
# Аналогично с family_status
family_status_df = df[['family_status','family_status_id']]

# %%
family_status_df.head(10)
# Out:
#       family_status  family_status_id
# 0   женат / замужем                 0
# 1   женат / замужем                 0
# 2   женат / замужем                 0
# 3   женат / замужем                 0
# 4  гражданский брак                 1
# 5  гражданский брак                 1
# 6   женат / замужем                 0
# 7   женат / замужем                 0
# 8  гражданский брак                 1
# 9   женат / замужем                 0

# %%
# Удалим из исходного датафрейма столбцы education и family_status, оставив только их идентификаторы
del df['education']

# %%
del df['family_status']

# %%
# Проверим
df.head()
# Out:
#    children  dob_years  education_id  family_status_id gender income_type  \
# 0         1         42             0                 0      F   сотрудник
# 1         1         36             1                 0      F   сотрудник
# 2         0         33             1                 0      M   сотрудник
# 3         3         32             1                 0      M   сотрудник
# 4         0         53             1                 1      F   пенсионер
#
#    debt  total_income                     purpose  years_employed
# 0     0        253875               покупка жилья              23
# 1     0        112080     приобретение автомобиля              11
# 2     0        145885               покупка жилья              15
# 3     0        267628  дополнительное образование              11
# 4     0        158616             сыграть свадьбу             932

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Принято.
#
# </div>

# %% [markdown]
# ### Шаг 2.6. Категоризация дохода.

# %%
# Создаём функцию с условиями
def income_status(total_income):
    if total_income <= 30000:
            return 'E'
    if total_income <= 50000:
            return 'D'
    if total_income <= 200000:
            return 'C'
    if total_income <= 1000000:
            return 'B'
    if total_income >= 1000001:
            return 'A'

# %%
df['income_status'] = df['total_income'].apply(income_status)

# %%
# Проверяем наличие столбца с категориями в таблице
df.head()
# Out:
#    children  dob_years  education_id  family_status_id gender income_type  \
# 0         1         42             0                 0      F   сотрудник
# 1         1         36             1                 0      F   сотрудник
# 2         0         33             1                 0      M   сотрудник
# 3         3         32             1                 0      M   сотрудник
# 4         0         53             1                 1      F   пенсионер
#
#    debt  total_income                     purpose  years_employed  \
# 0     0        253875               покупка жилья              23
# 1     0        112080     приобретение автомобиля              11
# 2     0        145885               покупка жилья              15
# 3     0        267628  дополнительное образование              11
# 4     0        158616             сыграть свадьбу             932
#
#   income_status
# 0             B
# 1             C
# 2             C
# 3             B
# 4             C

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Если интересно, могу рассказать, как лучше делать категоризацию количественных данных.
#
# </div>

# %% [markdown]
# ### Шаг 2.7. Категоризация целей кредита.

# %%
# # Напишем функцию для более точного отображения целей кредита
def credit_purpose_status(purpose):
    if 'образован' in purpose:
            return 'получение образования'
    if 'авто' in purpose:
            return 'операции с автомобилем'
    if 'свадь' in purpose:
            return 'проведение свадьбы'
    if 'жиль' or 'недв' in purpose:
            return 'операции с недвижимостью'
    return 'Не удалось идентифицировать'

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍 Здорово, что добавил проверку на другие значения.
#
# </div>

# %%
df['purpose_category'] = df['purpose'].apply(credit_purpose_status)

# %%
# Проверяем наличие столбца с категориями в таблице
df.head()
# Out:
#    children  dob_years  education_id  family_status_id gender income_type  \
# 0         1         42             0                 0      F   сотрудник
# 1         1         36             1                 0      F   сотрудник
# 2         0         33             1                 0      M   сотрудник
# 3         3         32             1                 0      M   сотрудник
# 4         0         53             1                 1      F   пенсионер
#
#    debt  total_income                     purpose  years_employed  \
# 0     0        253875               покупка жилья              23
# 1     0        112080     приобретение автомобиля              11
# 2     0        145885               покупка жилья              15
# 3     0        267628  дополнительное образование              11
# 4     0        158616             сыграть свадьбу             932
#
#   income_status          purpose_category
# 0             B  операции с недвижимостью
# ...

# %% [markdown]
# ### Ответы на вопросы.

# %% [markdown]
# ##### Вопрос 1:

# %% [markdown]
# Есть ли зависимость между количеством детей и возвратом кредита в срок?

# %% [markdown]
# Есть ли зависимость между семейным положением и возвратом кредита в срок?

# %% [markdown]
# Есть ли зависимость между уровнем дохода и возвратом кредита в срок?

# %% [markdown]
# Как разные цели кредита влияют на его возврат в срок?

# %% [markdown]
# ##### Вывод 1:

# %% [markdown]
# Есть ли зависимость между количеством детей и возвратом кредита в срок? - Есть:

# %%
children_set = df.groupby('children')['debt'].sum() / \
    df.groupby('children')['debt'].count() * 100

# %%
children_set
# Out:
# children
# 0    7.543822
# 1    9.165808
# 2    9.492481
# 3    8.181818
# 4    9.756098
# 5    0.000000
# Name: debt, dtype: float64

# %%
grouped_children = df.groupby('children')['debt'].count()
grouped_children
# Out:
# children
# 0    14091
# 1     4855
# 2     2128
# 3      330
# 4       41
# 5        9
# Name: debt, dtype: int64

# %% [markdown]
# <a id="cell_3_1"></a>
# <div class="alert alert-danger">
#
# **Артём:** ✋✋✋ Исходя из данных выше, доля невозврата у семей без детей 7.5%, у семей с одним ребенком 9.1%... Семьи без детей возвращают кредиты лучше.
#
# </div>

# %%
children_pivot = df.pivot_table(index = ['children'], \
                                columns = ['debt'], \
                                values = 'purpose', aggfunc='count')

children_pivot['ratio'] = children_pivot[1] / children_pivot[0] * 100
children_pivot
# Out:
# debt            0       1      ratio
# children
# 0         13028.0  1063.0   8.159349
# 1          4410.0   445.0  10.090703
# 2          1926.0   202.0  10.488058
# 3           303.0    27.0   8.910891
# 4            37.0     4.0  10.810811
# 5             9.0     NaN        NaN

# %% [markdown]
# Из результатот видно, что доля невозврата кредитов меньше всего у клиентов без детей, а именно 7.5%. В то время, как у клиентов с детьми этот показатель хуже. Зависимость присутствует, например разница в проценте возварщаемости кредитов у клиентов без детей и клиентов, хотя-бы с одним ребенком, - почти 2%. Возможно это не много на первый взгяд, но для банка это будет играть существенную роль при одобрении кредита.

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍👍👍👍👍 Отлично.
#
# </div>

# %% [markdown]
# <a id="cell_69"></a>
# <div class="alert alert-danger">
#
# **Артём:** ✋✋ Зависимость все же есть. Действительно несколько процентных пунктов - это не так много, но учитывая [уровень долговой нагрузки населения России перед банками](https://www.rbc.ru/finances/11/08/2021/6112dc5f9a79473a5acea094?), а это 23’900’000’000’000˙₽, лучше указать в финальном выводе.
#
# </div>

# %% [markdown]
# Есть ли зависимость между семейным положением и возвратом кредита в срок? - Есть:

# %%
family_status_set = df.groupby('family_status_id')['debt'].sum() / \
      df.groupby('family_status_id')['debt'].count() * 100

# %%
family_status_set
# Out:
# family_status_id
# 0    7.545182
# 1    9.347145
# 2    6.569343
# 3    7.112971
# 4    9.750890
# Name: debt, dtype: float64

# %%
family_status_pivot = df.pivot_table(index=['family_status_id'], columns=['debt'], values='total_income', aggfunc='count')
family_status_pivot['ratio'] = family_status_pivot[1] / family_status_pivot[0] * 100
family_status_pivot
# Out:
# debt                  0    1      ratio
# family_status_id
# 0                 11408  931   8.160940
# 1                  3763  388  10.310922
# 2                   896   63   7.031250
# 3                  1110   85   7.657658
# 4                  2536  274  10.804416

# %% [markdown]
# Зависимость пристуствует, семейное положение влияет, самые высоке показатели возвращаемости кредитов у разведенных и вдов. А самые низкие у тех кто не был в браке, и у тех кто в гражданском браке. Возможно опыт брака, даже бывшего, в положительной степени влиет на возращаемость кредитов.

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍👍👍👍👍 Молодец.
#
# </div>

# %% [markdown]
# <a id="cell_72"></a>
# <div class="alert alert-danger">
#
# **Артём:** ✋✋ Судя по твоей таблице самые низкие показатели у тех кто не был в браке, и у тех кто в граждансуом браке.
#
# </div>

# %% [markdown]
# Есть ли зависимость между уровнем дохода и возвратом кредита в срок? - Есть:

# %%
df['total_income'].quantile([0.25,0.5,0.75])
# Out:
# 0.25     89088.50
# 0.50    135781.00
# 0.75    195813.25
# Name: total_income, dtype: float64

# %%
# Так как мы не знаем социального контекста, то распределим уровень дохода на 4 группы
# Присвоим статусы каждой группе
def income_status(total_income):
    if total_income <= 89088.5:
            return 'Низкий уровень дохода'
    if total_income <= 135781.0:
            return 'Средний уровень дохода'
    if total_income < 195813.25:
            return 'Высокий уровень дохода'
    return 'Сверхвысокий уровень дохода'

# %%
df['income_status'] = df['total_income'].apply(income_status)

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍👍 Отлично.
#
# </div>

# %%
df.head()
# Out:
#    children  dob_years  education_id  family_status_id gender income_type  \
# 0         1         42             0                 0      F   сотрудник
# 1         1         36             1                 0      F   сотрудник
# 2         0         33             1                 0      M   сотрудник
# 3         3         32             1                 0      M   сотрудник
# 4         0         53             1                 1      F   пенсионер
#
#    debt  total_income                     purpose  years_employed  \
# 0     0        253875               покупка жилья              23
# 1     0        112080     приобретение автомобиля              11
# 2     0        145885               покупка жилья              15
# 3     0        267628  дополнительное образование              11
# 4     0        158616             сыграть свадьбу             932
#
#                  income_status          purpose_category
# 0  Сверхвысокий уровень дохода  операции с недвижимостью
# ...

# %%
monthly_income_set = df.groupby('income_status')['debt'].sum() / \
      df.groupby('income_status')['debt'].count() * 100

# %%
monthly_income_set.sort_values()
# Out:
# income_status
# Сверхвысокий уровень дохода    7.140194
# Низкий уровень дохода          7.811335
# Средний уровень дохода         8.539996
# Высокий уровень дохода         8.968861
# Name: debt, dtype: float64

# %%
monthly_income_pivot = df.pivot_table(index=['income_status'], columns=['debt'], values='education_id', aggfunc='count')
monthly_income_pivot['ratio'] = monthly_income_pivot[1] / monthly_income_pivot[0] * 100
monthly_income_pivot
# Out:
# debt                            0    1     ratio
# income_status
# Высокий уровень дохода       4882  481  9.852519
# Низкий уровень дохода        4945  419  8.473205
# Сверхвысокий уровень дохода  4981  383  7.689219
# Средний уровень дохода       4905  458  9.337411

# %%
# Проверим количество людей в каждой из групп
df['income_status'].value_counts(normalize = True)
# Out:
# Низкий уровень дохода          0.250023
# Сверхвысокий уровень дохода    0.250023
# Средний уровень дохода         0.249977
# Высокий уровень дохода         0.249977
# Name: income_status, dtype: float64

# %% [markdown]
# Присутствует незначительная разница по возвращаемости кредита в срок в зависимости от дохода. Лучше всего покатель у людей со сверхвысокими и низкими доходами. Если с хорошая возвращаемость кредитов у людей со сверхвысоким уровнем дохода  не вызывает вопросов, то причины почему люди с низким уовнем дохода возвращают кредиты лучше людей с высоким и среднем уровнем выглядят интересными. И возможно потребут отдельного анализа в будущем.

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍👍👍👍👍 Принято.
#
# </div>

# %% [markdown]
# <a id="cell_80"></a>
# <div class="alert alert-danger">
#
# **Артём:** ✋✋ Я понял, ты переаутал логику. Если бы только 10% клиентов возвращали кредиты, то банки бы обанкротились. Это 10% тех кто не возвращает.
#
# </div>

# %% [markdown]
# Как разные цели кредита влияют на его возврат в срок:

# %%
# Вспомним шаг 2.7
credit_purpose_pivot = df.pivot_table(index=['purpose_category'], columns=['debt'], values='education_id', aggfunc='count')
credit_purpose_pivot['ratio'] = credit_purpose_pivot[1] / credit_purpose_pivot[0] * 100
credit_purpose_pivot
# Out:
# debt                          0    1      ratio
# purpose_category
# операции с автомобилем     3903  403  10.325391
# операции с недвижимостью  10029  782   7.797388
# получение образования      3643  370  10.156464
# проведение свадьбы         2138  186   8.699719

# %% [markdown]
# Лучше всего выглядят свадьбы и недвижимость, хуже - образование и автомобили. Выглядит не совсем логично. Свадьбы — это не инвестиционный проект и это неликвидный кредит, который по сути проедают, однако возвращаемость по нему выше, чем на кредитах на получение образования. Ипотеки - самые крупные и рисковые кредитные сделки для частного лица, что сильнее стимулриует к возврату, нежели кредиты на автомобили.

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍👍👍👍👍 Молодец.
#
# </div>

# %% [markdown]
# <a id="cell_64"></a>
# <div class="alert alert-danger">
#
# **Артём:** ✋ На основании чего ты сделал эти выводы?
#
# </div>

# %% [markdown]
# ## Общий вывод:

# %% [markdown]
# В результате исследования были выявлены пропущенные значени в столбцах, аномалии и дупликаты. В первую очередь необходимо было избавиться от них для корректной работы с базой данных. Многие вещественные значения датафрейма, например в столбце total_income, были заменены на целочисленные. Были созданы новые датафреймы для упрощения работы, они заменяли значения соответсвенным числовым идентификатором.
# Есть зависимости между целями кредита, семейным положением, уровнем дохода и количеством детей в семье. Нельзя сказать, что они кардинально отличаются, но 2% на больших числах могут оказать существенное влияние на кредитный портфель банка. Учитывая при этом, что по состоянию на 2021 год Долг населения перед банками составил почти 24 трлн руб.
# Особое внимание следует уделить клиентам не бывавшим в браке, или находщихся в гражданском браке, клиентам с детьми, клиентам с высокими и средними доходами — с ними могут риски по невозврату кредитов выше. Также плохо выглядят кредиты на автомобили и образование, исследование показало наименьших рейтинг возврата по этим категориям.

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** 👍👍👍👍👍 Я бы добавил числа, но и так хорошо.
#
# </div>

# %% [markdown]
# <a id="cell_3_2"></a>
# <div class="alert alert-danger">
#
# **Артём:** ✋✋✋ Наоборот.
#
# </div>

# %% [markdown]
# Рекомендации для банка
# - Уделить внимание правилам валидации на сервере, чтобы больше не сталкиваться с проблемой дублей.
# - Продумать сценарий, когда отличается дата или время заявки, а уникальный идентификатор пользователя один и тот же,
#   иначе фактически дубли будут, но метод duplicated() их не найдет.
# - Считать стаж работы в годах, пользователи чаще всего не знают свой стаж в днях.
# - Показывать операторам в банке или пользователям на сайте подсказки заранее, когда вводят высокие/средние
#   значения в полях: возраст, стаж, наличие детей.
# - Блокировать отправку заявок с заведомо некорректными значениями, которые могут быть важны для анализа, например,
#   с отрицательным количеством детей.

# %% [markdown]
# <div class="alert alert-danger">
#
# **Артём:** ✋✋✋✋ Ты не исправил вывод в промежуточных выводах в последнем шаге. и не дал ответ заказчику на поставленные вопросы. Я не могу принять проект пока ты не ответишь корректно на вопросы.
#
# В брифе:
#
# Ответьте на вопросы
#
# * Есть ли зависимость между количеством детей и возвратом кредита в срок?
# * Есть ли зависимость между семейным положением и возвратом кредита в срок?
# * Есть ли зависимость между уровнем дохода и возвратом кредита в срок?
# * Как разные цели кредита влияют на его возврат в срок?
#
# </div>

# %% [markdown]
# <a id="cell_100"></a>
# <div class="alert alert-danger">
#
# **Артём:** ✋✋ Проект пишется для заказчика, он будет читать финальный вывод и только его. Добавь информации о проведенном исследовании, разбей по пунктам, сделай красиво, чтобы было понятно, что проведено настоящее исследование и выводу можно верить. Учитывай для кого проведено исследование, в банковской сфере даже сотые доли процента играют роль, но в нашем можно ограничиться десятыми. Помни, вывод – это лицо аналитика. 😉
#
#
# </div>

# %% [markdown]
# ---

# %% [markdown]
# <div class="alert alert-danger">
#
# **Артём:** ✋ Руслан, проект не написан до конца, закончи исследование и присылай на проверку.
#
# Жду новую версию проекта. 🙂
#
# </div>

# %% [markdown]
# <a id="cell_80"></a>
# <div class="alert alert-danger">
#
# **Артём:** ✋✋ Руслан, ты переаутал логику. Если бы только 10% клиентов возвращали кредиты, то банки бы обанкротились. Это 10% тех кто не возвращает. Измени промежуточные выводы и допиши финальный и можно идти к заказчику.
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
#
# **Артём:** ✋✋✋ Ты делаешь некорректные выводы. Посмотри [подсказку](#cell_3_1)
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
#
# **Артём:** ✋✋✋✋ Ты не исправил вывод в промежуточных выводах в последнем шаге. и не дал ответ заказчику на поставленные вопросы. Я не могу принять проект пока ты не ответишь корректно на вопросы.
#
# В брифе:
#
# Ответьте на вопросы
#
# * Есть ли зависимость между количеством детей и возвратом кредита в срок?
# * Есть ли зависимость между семейным положением и возвратом кредита в срок?
# * Есть ли зависимость между уровнем дохода и возвратом кредита в срок?
# * Как разные цели кредита влияют на его возврат в срок?
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# **Артём:** ✌️ Руслан, спасибо за хорошую работу и внесенные корректировки! Критических замечаний нет.
#
# Поздравляю, **проект принят!** 🥳 🎉 Ты молодец!
#
# Желаю тебе успехов в дальнейшем обучении. 😉
#
# </div>

# %%
import datetime as dt
checkpoint = dt.datetime.now().strftime("%d.%m.%Y %H:%M")
print(f'Контрольная точка: {checkpoint}')
# Out:
# Контрольная точка: 14.08.2022 11:48
